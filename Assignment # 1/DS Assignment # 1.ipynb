# %% [markdown]
# # Data Science Course (Assignment # 1)

# %% [markdown]
# ### Q1) Write a python program to print the following string in a specific format.

# %%
poem = "Twinke,twinkle,little,star, \n \t How I wonder what your are! \n\t\t Up Above the world so high \n\t\t Like a diamond in the sky \n Twinke,twinkle,little,star, \n \t How I wonder what your are! ";
print(poem);
# Out:
# Twinke,twinkle,little,star,
#  	 How I wonder what your are!
# 		 Up Above the world so high
# 		 Like a diamond in the sky
#  Twinke,twinkle,little,star,
#  	 How I wonder what your are!

# %% [markdown]
# ### Q2) Write a python program to get the pyton version you are using.

# %%
import sys;
print("System Version");
print(sys.version);
# Out:
# System Version
# 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]

# %% [markdown]
# ### Q3) Write a python program to display the current date and time.

# %%
import datetime
now = datetime.datetime.now()
print("Current date and time is: ")
print(now.strftime("%y-%m-%d %H:%M:%S"))
# Out:
# Current date and time is:
# 21-12-29 00:02:39

# %% [markdown]
# ### Q4) Write a pyton program which accepts the radius of a circle from the user and compute the area.

# %%
radius = float(input("Enter a Radius of a Circle to Comput it's area: "));
pir = 3.142;
area =  (radius)**2 *  pir ;
print(area);
# Out:
# Enter a Radius of a Circle to Comput it's area: 7
# 153.958

# %% [markdown]
# ###  Q5) Write a python program which accepts user's first name and the last name and placed them in a reverse order with a space between them.

# %%
first_name = input("Enter Your First Name: ");
last_name = input("Enter Your Last Name: ");
name = last_name + " " + first_name;
print(name);
# Out:
# Enter Your First Name: Zuberi
# Enter Your Last Name: Mustafa
# Mustafa Zuberi

# %% [markdown]
# ### Q6) Write a python program whic takes two inputs form user and print them addition.

# %%
a = int(input("num1: "));
b = int(input("num2: "));
c = a + b;
print(c);
# Out:
# num1: 88
# num2: 12
# 100
